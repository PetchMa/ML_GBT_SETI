# %%
import pandas as pd 
from blimpy import Waterfall
# Using readlines()
file1 = open('fine_cadences.txt', 'r')
Lines = file1.readlines()


li = []
temp =0
count = 0
for el in range(len(Lines)):
    if el%7==0:
        temp = el
        li.append(Lines[el].strip().replace('----- cadence: ',''))
        index = Lines[el+1].strip().find(':')
        fchan = Waterfall('../../../../../../..'+Lines[el+1].strip()[index+2:].replace('*','').replace(' ',''), load_data= False).header['fch1']
        if fchan<2000:
            count+=1
    else:
        index = Lines[el].strip().find(':')
        li.append(Lines[el].strip()[index+1:].replace('*',''))

print(count)
# total = {}
# for i in range(len(li)//7):
#     temp= li[i*7:(i+1)*7]
#     total[temp[0]] = temp[1:7]


# df = pd.DataFrame(total)
# Out:
# 1073

# %%
import pandas as pd 
# Using readlines()
file1 = open('fine_cadences.txt', 'r')
Lines = file1.readlines()


li = []
temp =0
for el in range(len(Lines)):
    if el%7==0:
        temp = el
        li.append(Lines[el].strip().replace('----- cadence: ','').replace("--- cadence: ",''))
    else:
        index = Lines[el].strip().find(':')
        li.append(Lines[el].strip()[index+2:].replace('*','').replace(' ',''))

total = {}
for i in range(len(li)//7):
    temp= li[i*7:(i+1)*7]
    total[temp[0]+"-"+str(i)] = temp[1:7]


final ={}
for key in total:
    fchan = Waterfall('../../../../../../..'+total[key][0], load_data= False).header['fch1']
    flag = True
    for i in range(6):
        time =  Waterfall('../../../../../../..'+total[key][i], load_data= False).selection_shape[0]
        if time!=16:
            flag = False
    if fchan< 2000 and flag:
        final[key] = total[key]

# final ={}
# for key in total:
#     fchan = Waterfall('../../../../../../..'+total[key][0], load_data= False).header['fch1']
#     if fchan< 2000:
#         final[key] = total[key]
    


df = pd.DataFrame(final)
print(df.header)
# df.to_csv("fine_cadences_formatted.csv", )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-d937c761789e> in <module>
#      26     flag = True
#      27     for i in range(6):
# ---> 28         time =  Waterfall('../../../../../../..'+total[key][i], load_data= False).selection_shape[0]
#      29         if time!=16:
#      30             flag = False
#
# ~/.local/lib/python3.6/site-packages/blimpy/waterfall.py in __init__(self, filename, f_start, f_stop, t_start, t_stop, load_data, max_load, header_dict, data_array)
#      98             self.ext = os.path.splitext(filename)[-1].lower()
#      99             self.container = fw.open_file(filename, f_start=f_start, f_stop=f_stop, t_start=t_start, t_stop=t_stop,
# --> 100                                           load_data=load_data, max_load=max_load)
#     101             self.file_header = self.container.header
#     102             self.header = self.file_header
#
# ~/.local/lib/python3.6/site-packages/blimpy/io/file_wrapper.py in open_file(filename, f_start, f_stop, t_start, t_stop, load_data, max_load)
#      42         ext = bytes(ext, 'ascii')
#      43
# ---> 44     if h5py.is_hdf5(filename):
#      45         # Open HDF5 file
#      46         return H5Reader(filename, f_start=f_start, f_stop=f_stop, t_start=t_start, t_stop=t_stop,
#
# /usr/local/lib/python3.6/dist-packages/h5py/_hl/base.py in is_hdf5(fname)
#      42
#      43         if os.path.isfile(fname):
# ---> 44             return h5f.is_hdf5(filename_encode(fname))
#      45         return False
#      46
#
# KeyboardInterrupt:

# %%
df = pd.read_csv('fine_cadences_formatted_updated_big.csv')
li = list(df.columns.values[1:])
print(len(li))
for i in range(len(li)):
    string = li[i].split('-')
    li[i] = string[0]
print(len(set(li)))
# Out:
# 2274
# 1316

# %%
df = pd.read_csv('L_band_directory.csv')
df
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             0
# 1           1             1
# 2           2             2
# 3           3             3
# 4           4             4
# 5           5             5
#
#                                            HIP110750  \
# 0  mnt_blpd7/datax2/dl/GBT_57654_18615_HIP110750_...
# 1  mnt_blpd7/datax2/dl/GBT_57654_18957_HIP109675_...
# 2  mnt_blpd7/datax2/dl/GBT_57654_19299_HIP110750_...
# 3  mnt_blpd7/datax2/dl/GBT_57654_19640_HIP109685_...
# 4  mnt_blpd7/datax2/dl/GBT_57654_19981_HIP110750_...
# 5  mnt_blpd7/datax2/dl/GBT_57654_20322_HIP109822_...
#
#                                             HIP15638  \
# 0  mnt_blpd7/datax2/dl/GBT_57750_08693_HIP15638_f...
# 1  mnt_blpd7/datax2/dl/GBT_57750_09022_HIP14844_f...
# 2  mnt_blpd7/datax2/dl/GBT_57750_09351_HIP15638_f...
# 3  mnt_blpd7/datax2/dl/GBT_57750_09701_HIP16191_f...
# 4  mnt_blpd7/datax2/dl/GBT_57750_10051_HIP15638_f...
# 5  mnt_blpd7/datax2/dl/GBT_57750_10390_HIP16276_f...
#
#                                            HIP100859  \
# 0  mnt_blpd7/datax2/dl/GBT_57667_83770_HIP100859_...
# 1  mnt_blpd7/datax2/dl/GBT_57667_84123_HIP100162_...
# 2  mnt_blpd7/datax2/dl/GBT_57667_84476_HIP100859_...
# 3  mnt_blpd7/datax2/dl/GBT_57667_84827_HIP100255_...
# 4  mnt_blpd7/datax2/dl/GBT_57667_85179_HIP100859_...
# 5  mnt_blpd7/datax2/dl/GBT_57667_85534_HIP100271_...
#
#                                             HIP53910  \
# 0  mnt_blpd7/datax/dl/GBT_57578_04024_HIP53910_fi...
# 1  mnt_blpd7/datax/dl/GBT_57578_04370_HIP53127_fi...
# 2  mnt_blpd7/datax/dl/GBT_57578_04716_HIP53910_fi...
# 3  mnt_blpd7/datax/dl/GBT_57578_05058_HIP53209_fi...
# 4  mnt_blpd7/datax/dl/GBT_57578_05400_HIP53910_fi...
# 5  mnt_blpd7/datax/dl/GBT_57578_05750_HIP53634_fi...
#
#                                            HIP113718  \
# 0  mnt_blpd7/datax2/dl/GBT_57848_53831_HIP113718_...
# 1  mnt_blpd7/datax2/dl/GBT_57848_54170_HIP112807_...
# 2  mnt_blpd7/datax2/dl/GBT_57848_54509_HIP113718_...
# 3  mnt_blpd7/datax2/dl/GBT_57848_54848_HIP112845_...
# 4  mnt_blpd7/datax2/dl/GBT_57848_55188_HIP113718_...
# 5  mnt_blpd7/datax2/dl/GBT_57848_55527_HIP112880_...
#
#                                             HIP34115  \
# 0  mnt_blpd7/datax/dl/GBT_57571_66683_HIP34115_fi...
# 1  mnt_blpd7/datax/dl/GBT_57571_67014_HIP33454_fi...
# 2  mnt_blpd7/datax/dl/GBT_57571_67346_HIP34115_fi...
